# %%
import pandas as pd

# %%
data = {
    "Hours_Studied": [4, 6, 5, 7, 3],
    "Attendance" : [80, 90, 85, 95, 70],
    "Assignment_Score": [75, 88, 82, 91, 65],
    "Sleep_Hours" : [6, 7, 5, None, 4],
    "Final_Grade": ["B", "A", "B", "A", "C"]
}

data
# Out:
# {'Hours_Studied': [4, 6, 5, 7, 3],
#  'Attendance': [80, 90, 85, 95, 70],
#  'Assignment_Score': [75, 88, 82, 91, 65],
#  'Sleep_Hours': [6, 7, 5, None, 4],
#  'Final_Grade': ['B', 'A', 'B', 'A', 'C']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Hours_Studied  Attendance  Assignment_Score  Sleep_Hours Final_Grade
# 0              4          80                75          6.0           B
# 1              6          90                88          7.0           A
# 2              5          85                82          5.0           B
# 3              7          95                91          NaN           A
# 4              3          70                65          4.0           C

# %%
df.head(2)
# Out:
#    Hours_Studied  Attendance  Assignment_Score  Sleep_Hours Final_Grade
# 0              4          80                75          6.0           B
# 1              6          90                88          7.0           A

# %%
a = df.columns
print(a)
# Out:
# Index(['Hours_Studied', 'Attendance', 'Assignment_Score', 'Sleep_Hours',
#        'Final_Grade'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.dtypes
# Out:
# Hours_Studied         int64
# Attendance            int64
# Assignment_Score      int64
# Sleep_Hours         float64
# Final_Grade          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_Studied     5 non-null      int64
#  1   Attendance        5 non-null      int64
#  2   Assignment_Score  5 non-null      int64
#  3   Sleep_Hours       4 non-null      float64
#  4   Final_Grade       5 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 332.0+ bytes

# %%
df.describe()
# Out:
#        Hours_Studied  Attendance  Assignment_Score  Sleep_Hours
# count       5.000000    5.000000          5.000000     4.000000
# mean        5.000000   84.000000         80.200000     5.500000
# std         1.581139    9.617692         10.473777     1.290994
# min         3.000000   70.000000         65.000000     4.000000
# 25%         4.000000   80.000000         75.000000     4.750000
# 50%         5.000000   85.000000         82.000000     5.500000
# 75%         6.000000   90.000000         88.000000     6.250000
# max         7.000000   95.000000         91.000000     7.000000

# %%
df.notnull().sum()
# Out:
# Hours_Studied       5
# Attendance          5
# Assignment_Score    5
# Sleep_Hours         4
# Final_Grade         5
# dtype: int64

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Assignment_Score  Sleep_Hours Final_Grade
# 0              4          80                75          6.0           B
# 1              6          90                88          7.0           A
# 2              5          85                82          5.0           B
# 3              7          95                91          5.5           A
# 4              3          70                65          4.0           C

# %%
df['Sleep_Hours'].fillna(df['Sleep_Hours'].mean(), inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12696\3192260044.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sleep_Hours'].fillna(df['Sleep_Hours'].mean(), inplace=True)

# %%
df
# Out:
#    Hours_Studied  Attendance  Assignment_Score  Sleep_Hours Final_Grade
# 0              4          80                75          6.0           B
# 1              6          90                88          7.0           A
# 2              5          85                82          5.0           B
# 3              7          95                91          5.5           A
# 4              3          70                65          4.0           C

# %%
df['Attendance'].mean()
# Out:
# np.float64(84.0)

# %%
df['Final_Grade'].unique()
# Out:
# array(['B', 'A', 'C'], dtype=object)
